# %% [markdown]
# # Recurrent Neural Networks | LSTM Price Movement Predictions For Trading Algorithms

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pandas_datareader import data as web
import yfinance as yf
import seaborn as sb
import tensorflow
import pandas_ta as ta

# %% [markdown]
# # 1. Gathering Data

# %%
tickers = ["BBAS3.SA"]
yf.pdr_override()
start_date = "2020-01-01"
end_date = datetime.today().strftime('%Y-%m-%d')
data = web.get_data_yahoo(tickers, start=start_date, end=end_date)
data.head()
data.shape[0]
# %%
#Segmentando Dataframe para obter valores de interesse
data_close = pd.DataFrame(data["Adj Close"])
data_close.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Adj Close
# Date
# 2020-01-02  41.224869
# 2020-01-03  41.155910
# 2020-01-06  40.611866
# 2020-01-07  40.305359
# 2020-01-08  39.937546

# %%
sb.set_palette('viridis')
sb.set_style('darkgrid')
plt.figure(figsize=(20,6))
plt.plot(data_close.index, data_close['Adj Close'])
plt.show()

# %% [markdown]
# # 2. Data Treatment

# %%
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %% [raw]
# Input Data:
# 4 previous days of: Open, High, Low, Close.
#
# Output Data:
# Next day Adj Close.

# %% [markdown]
# # 3. Data Analysis

# %%
data['RSI'] = ta.rsi(data.Close, length=15)
data['EMAFast'] = ta.rsi(data.Close, length=20)
data['EMAMedium'] = ta.rsi(data.Close, length=100)
data['EMASlow'] = ta.rsi(data.Close, length=150)

data['Target'] = data['Adj Close'] - data.Open
data['Target'] = data['Target'].shift(-1) #To get next day target value.

data['TargetClass'] = [1 if data.Target[i]>0 else 0 for i in range(len(data))]
data['TargetNextClose'] = data['Adj Close'].shift(-1)

data.dropna(inplace=True)
data.reset_index(inplace=True)
data.drop(['Volume', 'Close', 'Date'], axis=1, inplace=True)
data_set = data.iloc[:, 0:11] #
pd.set_option('display.max_columns', None)
data_set.head()
# Out:
# C:\Users\z004s8rp\AppData\Local\Temp\ipykernel_35772\3465581769.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data['TargetClass'] = [1 if data.Target[i]>0 else 0 for i in range(len(data))]
#         Open       High        Low  Adj Close        RSI    EMAFast  \
# 0  34.000000  34.939999  33.599998  26.505211  50.238833  51.026721
# 1  34.119999  34.599998  33.750000  26.753860  51.878577  52.182018
# 2  34.599998  34.889999  33.900002  26.365337  49.166284  50.232980
# 3  34.000000  34.419998  33.200001  26.225468  48.194407  49.531906
# 4  33.889999  34.400002  33.049999  25.697073  44.624045  46.927465
#
#    EMAMedium    EMASlow    Target  TargetClass  TargetNextClose
# 0  46.824639  45.852613 -7.366138            0        26.753860
# 1  47.051461  46.034815 -8.234661            0        26.365337
# 2  46.736818  45.792436 -7.774532            0        26.225468
# 3  46.623442  45.705223 -8.192926            0        25.697073
# 4  46.195818  45.376554 -7.317450            0        25.782549

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
data_set_scaled = sc.fit_transform(data_set)
print(data_set_scaled)
# Out:
# [[0.20392277 0.20325459 0.20536822 ... 0.20210392 0.         0.11417245]
#  [0.20765873 0.19240583 0.21004992 ... 0.12235574 0.         0.10362217]
#  [0.22260268 0.20165921 0.21473161 ... 0.16460499 0.         0.09982404]
#  ...
#  [0.95703608 0.9629866  0.96691631 ... 0.89407565 1.         0.98302232]
#  [0.96917815 0.97543074 0.97971281 ... 0.79674616 0.         0.95885454]
#  [0.97447074 0.96841092 0.95755304 ... 0.87571148 0.         0.96048376]]

# %%
X = []
backcandles = 10 #Number of days we wanna to look back in the past to predict next closing price day.
print(data_set_scaled.shape[0])
for j in range(8):
    X.append([])
    for i in range(backcandles, data_set_scaled.shape[0]):
        X[j].append(data_set_scaled[i-backcandles:i, j])
X = np.moveaxis(X, [0], [2])
X, yi = np.array(X), np.array(data_set_scaled[backcandles:,-1])
y = np.reshape(yi, (len(yi), 1))

print(X.shape)
print(y.shape)
# Out:
# 884
# (874, 10, 8)
# (874, 1)

# %%
splitlimit_test = int(len(X) * 0.9)
splitlimit_val = int(len(X) * 0.8)

X_train, X_test, X_val = X[:splitlimit_val], X[splitlimit_val:splitlimit_test], X[splitlimit_test:]
y_train, y_test, y_val = y[:splitlimit_val], y[splitlimit_val:splitlimit_test], y[splitlimit_test:]
# Out:
# 699

# %%
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import TimeDistributed
from tensorflow.keras import layers

import tensorflow as tf
import keras
from keras.callbacks import History
from keras.layers import LSTM, Input, Activation, concatenate
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %%
lstm_input = Input(shape=(backcandles, 8), name='lstm_input')
inputs = LSTM(150, name='first_layer')(lstm_input)
inputs = Dense(1, name='dense_layer')(inputs)
output = Activation('linear', name='output')(inputs)
model = Model(inputs=lstm_input, outputs=output)
adam = optimizers.Adam()
model.compile(optimizer=adam, loss='mse')
model.fit(x=X_train, y=y_train, batch_size=15, epochs=30, shuffe=False)

# %%
model = Sequential([layers.Input((backcandles, 8)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

# %%
model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)
model.summary()
# %%
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0252 - mean_absolute_error: 0.1129 - val_loss: 0.0500 - val_mean_absolute_error: 0.2063
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0405 - val_loss: 0.0065 - val_mean_absolute_error: 0.0655
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0329 - val_loss: 0.0033 - val_mean_absolute_error: 0.0464
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 0.0032 - val_mean_absolute_error: 0.0464
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0271 - val_loss: 7.6492e-04 - val_mean_absolute_error: 0.0226
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 6.6631e-04 - val_mean_absolute_error: 0.0213
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 6.0510e-04 - val_mean_absolute_error: 0.0196
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3491e-04 - mean_absolute_error: 0.0224 - val_loss: 9.0509e-04 - val_mean_absolute_error: 0.0259
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4908e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0024 - val_mean_absolute_error: 0.0441
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3469e-04 - mean_absolute_error: 0.0216 - val_loss: 6.7337e-04 - val_mean_absolute_error: 0.0200
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0240 - val_loss: 5.9532e-04 - val_mean_absolute_error: 0.0203
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8476e-04 - mean_absolute_error: 0.0205 - val_loss: 5.3724e-04 - val_mean_absolute_error: 0.0190
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6102e-04 - mean_absolute_error: 0.0191 - val_loss: 5.5807e-04 - val_mean_absolute_error: 0.0194
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5717e-04 - mean_absolute_error: 0.0203 - val_loss: 8.4712e-04 - val_mean_absolute_error: 0.0246
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1067e-04 - mean_absolute_error: 0.0213 - val_loss: 6.1047e-04 - val_mean_absolute_error: 0.0204
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1060e-04 - mean_absolute_error: 0.0203 - val_loss: 5.7467e-04 - val_mean_absolute_error: 0.0197
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9307e-04 - mean_absolute_error: 0.0198 - val_loss: 5.2418e-04 - val_mean_absolute_error: 0.0181
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5735e-04 - mean_absolute_error: 0.0218 - val_loss: 5.0760e-04 - val_mean_absolute_error: 0.0181
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4086e-04 - mean_absolute_error: 0.0201 - val_loss: 7.6750e-04 - val_mean_absolute_error: 0.0231
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7821e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0037 - val_mean_absolute_error: 0.0549
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6477e-04 - mean_absolute_error: 0.0218 - val_loss: 7.7866e-04 - val_mean_absolute_error: 0.0230
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2315e-04 - mean_absolute_error: 0.0200 - val_loss: 5.1049e-04 - val_mean_absolute_error: 0.0180
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1937e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0025 - val_mean_absolute_error: 0.0434
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4376e-04 - mean_absolute_error: 0.0215 - val_loss: 4.9984e-04 - val_mean_absolute_error: 0.0179
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5493e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4998e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0040 - val_mean_absolute_error: 0.0570
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1852e-04 - mean_absolute_error: 0.0200 - val_loss: 9.9431e-04 - val_mean_absolute_error: 0.0253
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8490e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0033 - val_mean_absolute_error: 0.0498
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1208e-04 - mean_absolute_error: 0.0203 - val_loss: 7.0317e-04 - val_mean_absolute_error: 0.0210
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7918e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0037 - val_mean_absolute_error: 0.0538
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9265e-04 - mean_absolute_error: 0.0194 - val_loss: 5.4373e-04 - val_mean_absolute_error: 0.0182
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6977e-04 - mean_absolute_error: 0.0180 - val_loss: 5.6826e-04 - val_mean_absolute_error: 0.0189
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0820e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0055 - val_mean_absolute_error: 0.0664
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7580e-04 - mean_absolute_error: 0.0224 - val_loss: 8.1116e-04 - val_mean_absolute_error: 0.0220
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5485e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0028 - val_mean_absolute_error: 0.0463
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9174e-04 - mean_absolute_error: 0.0203 - val_loss: 6.0228e-04 - val_mean_absolute_error: 0.0190
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8802e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5024e-04 - mean_absolute_error: 0.0185 - val_loss: 5.6001e-04 - val_mean_absolute_error: 0.0185
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9679e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0019 - val_mean_absolute_error: 0.0356
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0730e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0040 - val_mean_absolute_error: 0.0546
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7981e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0026 - val_mean_absolute_error: 0.0426
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4787e-04 - mean_absolute_error: 0.0174 - val_loss: 6.1505e-04 - val_mean_absolute_error: 0.0191
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2947e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0033 - val_mean_absolute_error: 0.0483
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1398e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3563e-04 - mean_absolute_error: 0.0187 - val_loss: 9.4969e-04 - val_mean_absolute_error: 0.0225
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1702e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0046 - val_mean_absolute_error: 0.0590
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2727e-04 - mean_absolute_error: 0.0221 - val_loss: 9.5245e-04 - val_mean_absolute_error: 0.0250
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3768e-04 - mean_absolute_error: 0.0185 - val_loss: 8.5337e-04 - val_mean_absolute_error: 0.0214
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7248e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4100e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0021 - val_mean_absolute_error: 0.0371
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8226e-04 - mean_absolute_error: 0.0178 - val_loss: 6.5046e-04 - val_mean_absolute_error: 0.0188
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1776e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0041 - val_mean_absolute_error: 0.0544
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4579e-04 - mean_absolute_error: 0.0188 - val_loss: 6.3815e-04 - val_mean_absolute_error: 0.0194
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3172e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0034 - val_mean_absolute_error: 0.0491
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8604e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0031 - val_mean_absolute_error: 0.0460
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7519e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0024 - val_mean_absolute_error: 0.0390
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3760e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0024 - val_mean_absolute_error: 0.0393
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6049e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0019 - val_mean_absolute_error: 0.0333
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9948e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0020 - val_mean_absolute_error: 0.0341
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8299e-04 - mean_absolute_error: 0.0165 - val_loss: 7.6339e-04 - val_mean_absolute_error: 0.0215
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9248e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0063 - val_mean_absolute_error: 0.0680
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4631e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0018 - val_mean_absolute_error: 0.0316
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1205e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0068 - val_mean_absolute_error: 0.0712
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9828e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0021 - val_mean_absolute_error: 0.0348
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7878e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0036 - val_mean_absolute_error: 0.0486
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8000e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0020 - val_mean_absolute_error: 0.0333
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3244e-04 - mean_absolute_error: 0.0186 - val_loss: 8.1238e-04 - val_mean_absolute_error: 0.0214
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0412e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0034 - val_mean_absolute_error: 0.0478
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8205e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0037 - val_mean_absolute_error: 0.0504
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8235e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0059 - val_mean_absolute_error: 0.0654
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1433e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0048 - val_mean_absolute_error: 0.0571
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3652e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0033 - val_mean_absolute_error: 0.0449
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1826e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0037 - val_mean_absolute_error: 0.0485
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9884e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0048 - val_mean_absolute_error: 0.0556
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2101e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0040 - val_mean_absolute_error: 0.0501
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7374e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0039 - val_mean_absolute_error: 0.0495
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2893e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0054 - val_mean_absolute_error: 0.0604
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1233e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0013 - val_mean_absolute_error: 0.0258
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6790e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0055 - val_mean_absolute_error: 0.0611
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2639e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0076 - val_mean_absolute_error: 0.0748
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1991e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0099e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0041 - val_mean_absolute_error: 0.0531
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2893e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5209e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0025 - val_mean_absolute_error: 0.0385
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9054e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0042 - val_mean_absolute_error: 0.0514
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8690e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0016 - val_mean_absolute_error: 0.0281
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0296e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0067 - val_mean_absolute_error: 0.0692
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4418e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0067 - val_mean_absolute_error: 0.0677
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4787e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0011 - val_mean_absolute_error: 0.0270
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1906e-04 - mean_absolute_error: 0.0205 - val_loss: 9.4296e-04 - val_mean_absolute_error: 0.0216
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1952e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0029 - val_mean_absolute_error: 0.0411
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8389e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0052 - val_mean_absolute_error: 0.0596
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4789e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0032 - val_mean_absolute_error: 0.0447
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6387e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0061 - val_mean_absolute_error: 0.0647
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7141e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0024 - val_mean_absolute_error: 0.0361
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1695e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0068 - val_mean_absolute_error: 0.0684
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8941e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0025 - val_mean_absolute_error: 0.0366
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9405e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0130 - val_mean_absolute_error: 0.1002
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4454e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0054 - val_mean_absolute_error: 0.0595
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3356e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0023 - val_mean_absolute_error: 0.0354
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          18,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 62,405 (243.77 KB)
#  Trainable params: 20,801 (81.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 41,604 (162.52 KB)

# %%
train_predictions = model.predict(X_train).flatten()

plt.figure(figsize=(20,6))
plt.plot(train_predictions)
plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
plt.tick_params(axis='x', rotation=45)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
